# %%
# !pip install -q -U google-generativeai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.4/155.4 kB 3.5 MB/s eta 0:00:00

# %%
import os
os.environ["GEMINI_API_KEY"] = "YOUR_API_KEY"

# %%
import google.generativeai as genai
genai.configure(api_key=os.environ['GEMINI_API_KEY'])

# %%
model = genai.GenerativeModel('gemini-2.0-flash-exp')

# %%
response = model.generate_content('Where is lifespan of butterfly')
print(response.text)
# Out:
# The lifespan of a butterfly varies greatly depending on the species. Some butterflies live only a few days, while others can live for several months.
#
# Here's a general breakdown:
#
# *   **Very Short-Lived Butterflies:** Some smaller butterfly species only live for a few days to a week. Their primary purpose as adults is to reproduce.
# *   **Short-Lived Butterflies:** Many common butterflies live for about two weeks.
# *   **Medium-Lived Butterflies:** Some butterflies can live for a month or two.
# *   **Long-Lived Butterflies:** Certain species, like Monarchs that overwinter, can live for up to nine months.

# %%
import pathlib
import textwrap

import google.generativeai as genai
from IPython.display import display, Markdown


def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

# %%
for m in genai.list_models():
  if 'generateContent' in m.supported_generation_methods:
    print(m.name)
# Out:
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro-vision
# models/gemini-1.5-pro-latest
# models/gemini-1.5-pro-001
# models/gemini-1.5-pro-002
# models/gemini-1.5-pro
# models/gemini-1.5-flash-latest
# models/gemini-1.5-flash-001
# models/gemini-1.5-flash-001-tuning
# models/gemini-1.5-flash
# models/gemini-1.5-flash-002
# models/gemini-1.5-flash-8b
# models/gemini-1.5-flash-8b-001
# models/gemini-1.5-flash-8b-latest
# models/gemini-1.5-flash-8b-exp-0827
# models/gemini-1.5-flash-8b-exp-0924
# models/gemini-2.5-pro-exp-03-25
# models/gemini-2.5-pro-preview-03-25
# models/gemini-2.5-flash-preview-04-17
# models/gemini-2.0-flash-exp
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-exp-image-generation
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.0-flash-lite-preview-02-05
# models/gemini-2.0-flash-lite-preview
# models/gemini-2.0-pro-exp
# models/gemini-2.0-pro-exp-02-05
# models/gemini-exp-1206
# models/gemini-2.0-flash-thinking-exp-01-21
# models/gemini-2.0-flash-thinking-exp
# models/gemini-2.0-flash-thinking-exp-1219
# models/learnlm-1.5-pro-experimental
# models/learnlm-2.0-flash-experimental
# models/gemma-3-1b-it
# models/gemma-3-4b-it
# models/gemma-3-12b-it
# models/gemma-3-27b-it

# %%
model = genai.GenerativeModel('gemini-2.0-pro-exp-02-05')

# %%
# %%time
response = model.generate_content("What is the meaning of dream & goal? how to reach the dream")
# Out:
# CPU times: user 360 ms, sys: 48.7 ms, total: 409 ms
# Wall time: 29.5 s

# %%
to_markdown(response.text)
# Out:
# > Okay, let's break down the meaning of "dream" and "goal" and then discuss how to reach a dream.
# >
# > **1. Meaning of Dream:**
# >
# > *   **Aspiration/Vision:** A dream, in this context, is a cherished aspiration, ambition, or ideal. It's often a big-picture vision of what you want to achieve, become, or experience in the future.
# > *   **Often Vague & Emotionally Driven:** Dreams tend to be more emotionally charged and sometimes less defined than goals. They represent a deep desire or longing. Think "I dream of being a successful writer" or "My dream is to travel the world."
# > *   **The "Why":** A dream often provides the underlying motivation, the "why" behind your efforts. It's the ultimate destination you're aiming for, even if the path isn't clear yet.
# > *   **Long-Term Focus:** Dreams usually relate to significant, long-term achievements or states of being.
# >
# > **2. Meaning of Goal:**
# >
# > *   **Specific Target:** A goal is a specific, measurable, achievable, relevant, and time-bound (SMART) objective. It's a concrete target you aim to hit.
# > *   **Action-Oriented:** Goals are designed to be acted upon. They require planning and deliberate effort. Think "My goal is to write 500 words every day this month" or "My goal is to save $5000 for travel by next December."
# > *   **The "How":** Goals represent the steps, the milestones, the "how" you will progress towards a larger vision (often, your dream).
# > *   **Shorter/Intermediate Term:** While you can have long-term goals, they are often intermediate steps that break down a larger ambition.
# >
# > **Relationship between Dreams and Goals:**
# >
# > Think of it like this:
# >
# > *   **Dream:** The inspiring mountain peak you want to reach.
# > *   **Goals:** The specific base camps you need to establish and the climbing routes you need to follow to get to the peak.
# >
# > You need the **dream** for inspiration and direction. You need **goals** to make the dream tangible and create a practical path forward. Goals turn the "someday I wish..." of a dream into "here's what I'm doing *today* to make it happen."
# >
# > **3. How to Reach the Dream:**
# >
# > Reaching a dream is a process, often long and challenging, that involves turning that abstract vision into concrete actions. Here’s a common approach:
# >
# > 1.  **Clarify and Define Your Dream:**
# >     *   **Get Specific:** What does "success," "happiness," or "fulfillment" actually look like for *you* in the context of your dream? The clearer the picture, the better. Visualize it. Write it down in detail.
# >     *   **Understand Your "Why":** Why is this dream important to you? Connecting with your deep motivations will fuel you through difficulties.
# >
# > 2.  **Break It Down into Goals (The Crucial Step):**
# >     *   **Identify Milestones:** What major achievements would signify progress towards your dream? These become your long-term goals.
# >     *   **Set SMART Goals:** For each milestone, set specific, measurable, achievable, relevant, and time-bound (SMART) short-term and medium-term goals.
# >         *   *Example:* Dream = Be a published author. Long-term goal = Get a publishing contract. Medium-term goal = Finish a manuscript draft in 1 year. Short-term goal = Write 1 chapter per month / Write 500 words 5 days a week.
# >
# > 3.  **Create an Action Plan:**
# >     *   **List Tasks:** For each goal, list the specific actions required to achieve it.
# >     *   **Prioritize:** What needs to be done first? What's most important?
# >     *   **Schedule:** Allocate time for these actions in your daily, weekly, and monthly schedule.
# >
# > 4.  **Take Consistent Action:**
# >     *   **Start Now:** Don't wait for the "perfect" moment. Begin with small, manageable steps.
# >     *   **Build Habits:** Consistency is key. Turn necessary actions into regular habits.
# >     *   **Focus:** Minimize distractions and concentrate on the task at hand.
# >
# > 5.  **Stay Persistent and Resilient:**
# >     *   **Expect Challenges:** Setbacks, failures, and obstacles are part of the journey. Don't let them derail you permanently.
# >     *   **Learn from Mistakes:** View failures as learning opportunities. Analyze what went wrong and adjust your approach.
# >     *   **Maintain Motivation:** Regularly remind yourself of your dream and your "why." Celebrate small wins along the way.
# >
# > 6.  **Be Flexible and Adaptable:**
# >     *   **Review and Adjust:** Your plan isn't set in stone. Regularly review your progress and be willing to adjust your goals or strategies as you learn more or circumstances change.
# >     *   **Embrace Change:** Sometimes the path to your dream might look different than you initially imagined. Be open to new possibilities.
# >
# > 7.  **Seek Support and Resources:**
# >     *   **Learn Continuously:** Acquire the skills and knowledge needed. Read books, take courses, find mentors.
# >     *   **Build a Network:** Connect with people who support you, inspire you, or have experience in the area of your dream. Share your goals with trusted friends or family.
# >
# > 8.  **Believe in Yourself:**
# >     *   **Cultivate a Positive Mindset:** Believe that you are capable of achieving your dream. Challenge negative self-talk.
# >     *   **Visualize Success:** Regularly imagine yourself having achieved your dream.
# >
# > In essence, reaching a dream involves translating the powerful emotion and vision of the dream into the structured, actionable steps of goal-setting, and then consistently executing those steps with persistence and adaptability.

# %%
response.prompt_feedback

# %%
response.candidates
# Out:
# [content {
#   parts {
#     text: "Okay, let\'s break down the meaning of \"dream\" and \"goal\" and then discuss how to reach a dream.\n\n**1. Meaning of Dream:**\n\n*   **Aspiration/Vision:** A dream, in this context, is a cherished aspiration, ambition, or ideal. It\'s often a big-picture vision of what you want to achieve, become, or experience in the future.\n*   **Often Vague & Emotionally Driven:** Dreams tend to be more emotionally charged and sometimes less defined than goals. They represent a deep desire or longing. Think \"I dream of being a successful writer\" or \"My dream is to travel the world.\"\n*   **The \"Why\":** A dream often provides the underlying motivation, the \"why\" behind your efforts. It\'s the ultimate destination you\'re aiming for, even if the path isn\'t clear yet.\n*   **Long-Term Focus:** Dreams usually relate to significant, long-term achievements or states of being.\n\n**2. Meaning of Goal:**\n\n*   **Specific Target:** A goal is a specific, measurable, achievable, relevant, and time-bound (SMART) objective. It\'s a concrete target you aim to hit.\n*   **Action-Oriented:** Goals are designed to be acted upon. They require planning and deliberate effort. Think \"My goal is to write 500 words every day this month\" or \"My goal is to save $5000 for travel by next December.\"\n*   **The \"How\":** Goals represent the steps, the milestones, the \"how\" you will progress towards a larger vision (often, your dream).\n*   **Shorter/Intermediate Term:** While you can have long-term goals, they are often intermediate steps that break down a larger ambition.\n\n**Relationship between Dreams and Goals:**\n\nThink of it like this:\n\n*   **Dream:** The inspiring mountain peak you want to reach.\n*   **Goals:** The specific base camps you need to establish and the climbing routes you need to follow to get to the peak.\n\nYou need the **dream** for inspiration and direction. You need **goals** to make the dream tangible and create a practical path forward. Goals turn the \"someday I wish...\" of a dream into \"here\'s what I\'m doing *today* to make it happen.\"\n\n**3. How to Reach the Dream:**\n\nReaching a dream is a process, often long and challenging, that involves turning that abstract vision into concrete actions. Here’s a common approach:\n\n1.  **Clarify and Define Your Dream:**\n    *   **Get Specific:** What does \"success,\" \"happiness,\" or \"fulfillment\" actually look like for *you* in the context of your dream? The clearer the picture, the better. Visualize it. Write it down in detail.\n    *   **Understand Your \"Why\":** Why is this dream important to you? Connecting with your deep motivations will fuel you through difficulties.\n\n2.  **Break It Down into Goals (The Crucial Step):**\n    *   **Identify Milestones:** What major achievements would signify progress towards your dream? These become your long-term goals.\n    *   **Set SMART Goals:** For each milestone, set specific, measurable, achievable, relevant, and time-bound (SMART) short-term and medium-term goals.\n        *   *Example:* Dream = Be a published author. Long-term goal = Get a publishing contract. Medium-term goal = Finish a manuscript draft in 1 year. Short-term goal = Write 1 chapter per month / Write 500 words 5 days a week.\n\n3.  **Create an Action Plan:**\n    *   **List Tasks:** For each goal, list the specific actions required to achieve it.\n    *   **Prioritize:** What needs to be done first? What\'s most important?\n    *   **Schedule:** Allocate time for these actions in your daily, weekly, and monthly schedule.\n\n4.  **Take Consistent Action:**\n    *   **Start Now:** Don\'t wait for the \"perfect\" moment. Begin with small, manageable steps.\n    *   **Build Habits:** Consistency is key. Turn necessary actions into regular habits.\n    *   **Focus:** Minimize distractions and concentrate on the task at hand.\n\n5.  **Stay Persistent and Resilient:**\n    *   **Expect Challenges:** Setbacks, failures, and obstacles are part o ...
#   }
#   role: "model"
# }
# finish_reason: STOP
# index: 0
# ]

# %%
for chunk in response:
  print(chunk.text)
  print("_"*5)
# Out:
# Okay, let's break down the meaning of "dream" and "goal" and then discuss how to reach a dream.
#
# **1. Meaning of Dream:**
#
# *   **Aspiration/Vision:** A dream, in this context, is a cherished aspiration, ambition, or ideal. It's often a big-picture vision of what you want to achieve, become, or experience in the future.
# *   **Often Vague & Emotionally Driven:** Dreams tend to be more emotionally charged and sometimes less defined than goals. They represent a deep desire or longing. Think "I dream of being a successful writer" or "My dream is to travel the world."
# *   **The "Why":** A dream often provides the underlying motivation, the "why" behind your efforts. It's the ultimate destination you're aiming for, even if the path isn't clear yet.
# *   **Long-Term Focus:** Dreams usually relate to significant, long-term achievements or states of being.
#
# **2. Meaning of Goal:**
#
# *   **Specific Target:** A goal is a specific, measurable, achievable, relevant, and time-bound (SMART) objective. It's a concrete target you aim to hit.
# *   **Action-Oriented:** Goals are designed to be acted upon. They require planning and deliberate effort. Think "My goal is to write 500 words every day this month" or "My goal is to save $5000 for travel by next December."
# *   **The "How":** Goals represent the steps, the milestones, the "how" you will progress towards a larger vision (often, your dream).
# *   **Shorter/Intermediate Term:** While you can have long-term goals, they are often intermediate steps that break down a larger ambition.
#
# **Relationship between Dreams and Goals:**
#
# Think of it like this:
#
# *   **Dream:** The inspiring mountain peak you want to reach.
# *   **Goals:** The specific base camps you need to establish and the climbing routes you need to follow to get to the peak.
#
# You need the **dream** for inspiration and direction. You need **goals** to make the dream tangible and create a practical path forward. Goals turn the "someday I wish..." of a dream into "here's what I'm doing *today* to make it happen."
#
# **3. How to Reach the Dream:**
#
# Reaching a dream is a process, often long and challenging, that involves turning that abstract vision into concrete actions. Here’s a common approach:
#
# 1.  **Clarify and Define Your Dream:**
#     *   **Get Specific:** What does "success," "happiness," or "fulfillment" actually look like for *you* in the context of your dream? The clearer the picture, the better. Visualize it. Write it down in detail.
#     *   **Understand Your "Why":** Why is this dream important to you? Connecting with your deep motivations will fuel you through difficulties.
#
# 2.  **Break It Down into Goals (The Crucial Step):**
#     *   **Identify Milestones:** What major achievements would signify progress towards your dream? These become your long-term goals.
#     *   **Set SMART Goals:** For each milestone, set specific, measurable, achievable, relevant, and time-bound (SMART) short-term and medium-term goals.
#         *   *Example:* Dream = Be a published author. Long-term goal = Get a publishing contract. Medium-term goal = Finish a manuscript draft in 1 year. Short-term goal = Write 1 chapter per month / Write 500 words 5 days a week.
#
# 3.  **Create an Action Plan:**
#     *   **List Tasks:** For each goal, list the specific actions required to achieve it.
#     *   **Prioritize:** What needs to be done first? What's most important?
#     *   **Schedule:** Allocate time for these actions in your daily, weekly, and monthly schedule.
#
# 4.  **Take Consistent Action:**
#     *   **Start Now:** Don't wait for the "perfect" moment. Begin with small, manageable steps.
#     *   **Build Habits:** Consistency is key. Turn necessary actions into regular habits.
#     *   **Focus:** Minimize distractions and concentrate on the task at hand.
#
# 5.  **Stay Persistent and Resilient:**
#     *   **Expect Challenges:** Setbacks, failures, and obstacles are part of the journey. Don't let them derail you permanently.
#     *   **Learn from Mistakes:** View failures as learning opportunities. Analyze what went wrong and adjust your approach.
#     *   **Maintain Motivation:** Regularly remind yourself of your dream and your "why." Celebrate small wins along the way.
#
# 6.  **Be Flexible and Adaptable:**
#     *   **Review and Adjust:** Your plan isn't set in stone. Regularly review your progress and be willing to adjust your goals or strategies as you learn more or circumstances change.
#     *   **Embrace Change:** Sometimes the path to your dream might look different than you initially imagined. Be open to new possibilities.
#
# 7.  **Seek Support and Resources:**
#     *   **Learn Continuously:** Acquire the skills and knowledge needed. Read books, take courses, find mentors.
#     *   **Build a Network:** Connect with people who support you, inspire you, or have experience in the area of your dream. Share your goals with trusted friends or family.
#
# 8.  **Believe in Yourself:**
#     *   **Cultivate a Positive Mindset:** Believe that you are capable of achieving your dream. Challenge negative self-talk.
#     *   **Visualize Success:** Regularly imagine yourself having achieved your dream.
#
# In essence, reaching a dream involves translating the powerful emotion and vision of the dream into the structured, actionable steps of goal-setting, and then consistently executing those steps with persistence and adaptability.
# _____

# %%
import PIL.Image

img = PIL.Image.open("/content/Screenshot (33).png")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x1080>

# %%
model = genai.GenerativeModel('models/gemini-2.0-pro-exp-02-05')

# %%
response = model.generate_content(img)

to_markdown(response.text)
# Out:
# > ```json
# > [
# >   {"box_2d": [53, 29, 84, 93], "label": "the text LOBBY"},
# >   {"box_2d": [129, 53, 144, 119], "label": "the text NOTIFICATIONS"},
# >   {"box_2d": [129, 128, 144, 158], "label": "the text PARTY"},
# >   {"box_2d": [128, 167, 144, 206], "label": "the text FRIENDS"},
# >   {"box_2d": [128, 215, 144, 224], "label": "the letter E"},
# >   {"box_2d": [129, 33, 144, 41], "label": "the number 0"},
# >   {"box_2d": [916, 452, 934, 539], "label": "the text MATCHMAKING..."},
# >   {"box_2d": [951, 482, 967, 517], "label": "the time 00:00:17"},
# >   {"box_2d": [971, 853, 986, 978], "label": "the text LOADING GAMEPLAY LEVEL"},
# >   {"box_2d": [934, 115, 949, 163], "label": "the text ADD FRIEND"},
# >   {"box_2d": [934, 96, 949, 104], "label": "the letter F"},
# >   {"box_2d": [934, 57, 949, 82], "label": "the text BACK"},
# >   {"box_2d": [934, 29, 949, 48], "label": "the text ESC"},
# >   {"box_2d": [61, 928, 75, 967], "label": "the text FRIENDS"},
# >   {"box_2d": [61, 899, 75, 908], "label": "the number 4"},
# >   {"box_2d": [58, 867, 74, 876], "label": "the letter F"},
# >   {"box_2d": [58, 840, 74, 854], "label": "the letter F1"},
# >   {"box_2d": [58, 816, 74, 824], "label": "the number 0"},
# >   {"box_2d": [58, 761, 74, 800], "label": "the text Luffy5126"},
# >   {"box_2d": [58, 739, 74, 747], "label": "the number 2"},
# >   {"box_2d": [58, 667, 74, 685], "label": "the number 800"},
# >   {"box_2d": [58, 595, 74, 613], "label": "the number 100"}
# > ]
# > ```

# %%
response = model.generate_content(["Write a short, engaging blog post based on this picture. It should include a description of the meal in the photo and talk about my journey meal prepping.", img], stream=True)
response.resolve()
to_markdown(response.text)
# Out:
# > Okay, I see the image you've sent, but it looks like a screenshot from a video game lobby, showing a soldier character. There isn't any food or meal prep visible in this picture.
# >
# > To write the blog post you're looking for – describing a specific meal and your meal prepping journey – I'll need the actual photo of your meal prep container!
# >
# > Once you provide the correct picture of your food, I'd be happy to write that short, engaging blog post for you. Just upload the right image, and let's get cooking (with words)! 😊

# %%
model = genai.GenerativeModel('models/gemini-2.0-pro-exp-02-05')
chat = model.start_chat(history=[])
chat
# Out:
# ChatSession(
#     model=genai.GenerativeModel(
#         model_name='models/gemini-2.0-pro-exp-02-05',
#         generation_config={},
#         safety_settings={},
#         tools=None,
#         system_instruction=None,
#         cached_content=None
#     ),
#     history=[]
# )

# %%
response = chat.send_message("In one sentence, explain how a computer works to a young child.")
to_markdown(response.text)
# Out:
# > A computer is like a super-fast helper that follows your instructions to play games, show pictures, or help you learn things.

# %%
chat.history
# Out:
# [parts {
#    text: "In one sentence, explain how a computer works to a young child."
#  }
#  role: "user",
#  parts {
#    text: "A computer is like a super-fast helper that follows your instructions to play games, show pictures, or help you learn things."
#  }
#  role: "model"]

# %%
response = chat.send_message("Okay, how about a more detailed explanation to a high schooler?", stream=True)

for chunk in response:
  print(chunk.text)
  print("_"*80)
# Out:
# Okay, for
# ________________________________________________________________________________
#  a high schooler:
#
# A computer fundamentally processes data by rapidly executing sequences of instructions stored in its memory (RAM)
# ________________________________________________________________________________
#  using a central processing unit (CPU); it takes input from devices like keyboards or mice, manipulates data represented as binary
# ________________________________________________________________________________
#  electrical signals (1s and 0s) using billions of tiny switches called transistors, stores information long-term on drives
# ________________________________________________________________________________
#  (like SSDs or HDDs), and presents the results via output devices like screens or speakers, all orchestrated by an
# ________________________________________________________________________________
#  operating system that manages hardware resources and runs application software.
# ________________________________________________________________________________

# %%
for message in chat.history:
  display(to_markdown(f'**{message.role}**: {message.parts[0].text}'))
# Out:
# > **user**: In one sentence, explain how a computer works to a young child.
# > **model**: A computer is like a super-fast helper that follows your instructions to play games, show pictures, or help you learn things.
# > **user**: Okay, how about a more detailed explanation to a high schooler?
# > **model**: Okay, for a high schooler:
# >
# > A computer fundamentally processes data by rapidly executing sequences of instructions stored in its memory (RAM) using a central processing unit (CPU); it takes input from devices like keyboards or mice, manipulates data represented as binary electrical signals (1s and 0s) using billions of tiny switches called transistors, stores information long-term on drives (like SSDs or HDDs), and presents the results via output devices like screens or speakers, all orchestrated by an operating system that manages hardware resources and runs application software.

# %%
model.count_tokens("What is the meaning of life?")
# Out:
# total_tokens: 7

# %%
model.count_tokens(chat.history)
# Out:
# total_tokens: 169

# %%
result = genai.embed_content(
    model="models/text-embedding-004",
    content="What is the meaning of life?",
    task_type="retrieval_document",
    title="Embedding of single string")

# 1 input > 1 vector output
print(str(result['embedding'])[:50], '... TRIMMED]')
# Out:
# [-0.02854543, 0.044588115, -0.034197364, -0.004266 ... TRIMMED]

# %%
result = genai.embed_content(
    model="models/text-embedding-004",
    content=[
      'What is the meaning of life?',
      'How much wood would a woodchuck chuck?',
      'How does the brain work?'],
    task_type="retrieval_document",
    title="Embedding of list of strings")

# A list of inputs > A list of vectors output
for v in result['embedding']:
  print(str(v)[:50], '... TRIMMED ...')
# Out:
# [-0.036453027, 0.033254996, -0.03970925, -0.002628 ... TRIMMED ...
# [-0.01591948, 0.032582663, -0.081024624, -0.011298 ... TRIMMED ...
# [0.00037063024, 0.03763057, -0.122695684, -0.00951 ... TRIMMED ...

# %%
response.candidates[0].content
# Out:
# parts {
#   text: "Okay, for a high schooler:\n\nA computer fundamentally processes data by rapidly executing sequences of instructions stored in its memory (RAM) using a central processing unit (CPU); it takes input from devices like keyboards or mice, manipulates data represented as binary electrical signals (1s and 0s) using billions of tiny switches called transistors, stores information long-term on drives (like SSDs or HDDs), and presents the results via output devices like screens or speakers, all orchestrated by an operating system that manages hardware resources and runs application software."
# }
# role: "model"

# %%
result = genai.embed_content(
    model = 'models/text-embedding-004',
    content = response.candidates[0].content)

# 1 input > 1 vector output
print(str(result['embedding'])[:50], '... TRIMMED ...')
# Out:
# [-0.012521684, 0.04143858, -0.08085076, -0.0294215 ... TRIMMED ...

# %%
chat.history
# Out:
# [parts {
#    text: "In one sentence, explain how a computer works to a young child."
#  }
#  role: "user",
#  parts {
#    text: "A computer is like a super-fast helper that follows your instructions to play games, show pictures, or help you learn things."
#  }
#  role: "model",
#  parts {
#    text: "Okay, how about a more detailed explanation to a high schooler?"
#  }
#  role: "user",
#  parts {
#    text: "Okay, for a high schooler:\n\nA computer fundamentally processes data by rapidly executing sequences of instructions stored in its memory (RAM) using a central processing unit (CPU); it takes input from devices like keyboards or mice, manipulates data represented as binary electrical signals (1s and 0s) using billions of tiny switches called transistors, stores information long-term on drives (like SSDs or HDDs), and presents the results via output devices like screens or speakers, all orchestrated by an operating system that manages hardware resources and runs application software."
#  }
#  role: "model"]

# %%
response = model.generate_content('[Questionable prompt here]')
response.candidates
# Out:
# [content {
#   parts {
#     text: "I cannot fulfill this request. It appears to violate my safety policies regarding harmful content.\n\nIf you have a different request that aligns with safety guidelines, I would be happy to help."
#   }
#   role: "model"
# }
# finish_reason: STOP
# index: 0
# ]

# %%
response.prompt_feedback

# %%
response = model.generate_content('[Questionable prompt here]',
                                  safety_settings={'HARASSMENT':'block_none'})
response.text
# Out:
# 'It seems you\'ve entered "[Questionable prompt here]" as a placeholder instead of providing an actual prompt.\n\nIf you have a specific prompt in mind that you consider "questionable," please provide it, and I will assess it based on my safety guidelines.\n\nI cannot generate responses that:\n\n1.  **Promote illegal acts or dangerous activities.**\n2.  **Contain hate speech, harassment, or discrimination.**\n3.  **Generate non-consensual sexual content.**\n4.  **Depict severe harm or graphic violence.**\n5.  **Violate privacy or share non-public information.**\n\nIf your prompt falls into any of these categories, I will have to decline it. If it\'s questionable for other reasons (e.g., ethically ambiguous, potentially biased, factually dubious), I will try to respond cautiously and responsibly.\n\nPlease provide the actual prompt you wanted to ask about.'

# %%
model = genai.GenerativeModel('gemini-1.5-flash')
response = model.generate_content(
    genai.protos.Content(
        parts = [
            genai.protos.Part(text="Write a short, engaging blog post based on this picture."),
            genai.protos.Part(
                inline_data=genai.protos.Blob(
                    mime_type='image/jpg',
                    data=pathlib.Path(r'/content/Screenshot (33).png').read_bytes()
                )
            ),
        ],
    ),
    stream=True)

# %%
response.resolve()

to_markdown(response.text[:100] + "... [TRIMMED] ...")
# Out:
# > ## Ready to Roll:  A Battlefield Briefing
# >
# > The red lights hum, casting long shadows in the pre-match... [TRIMMED] ...

# %%
response.resolve()

to_markdown(response.text[:100] + "... [TRIMMED] ...")
# Out:
# > ## Ready to Roll:  A Battlefield Briefing
# >
# > The red lights hum, casting long shadows in the pre-match... [TRIMMED] ...

# %%
model = genai.GenerativeModel('gemini-1.5-flash')
response = model.generate_content(
    'Tell me a story about a magic backpack.',
    generation_config=genai.types.GenerationConfig(
        # Only one candidate for now.
        candidate_count=1,
        stop_sequences=['x'],
        max_output_tokens=20,
        temperature=1.0)
)

# %%
text = response.text

if response.candidates[0].finish_reason.name == "MAX_TOKENS":
    text += '...'

to_markdown(text)
# Out:
# > Elara wasn't your average twelve-year-old. While other kids dreamed of ponies and...
